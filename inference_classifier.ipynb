# %%
import cv2
import numpy as np
import mediapipe as mp
from tensorflow.keras.models import load_model

model = load_model('hand_gesture_model.keras')

cap = cv2.VideoCapture(0)

mp_hands = mp.solutions.hands
mp_drawing = mp.solutions.drawing_utils
mp_drawing_styles = mp.solutions.drawing_styles

hands = mp_hands.Hands(static_image_mode=True, min_tracking_confidence=0.3)

labels_dict = {0: 'Allah', 1: 'Well Done', 2: 'Focus'}

while True:
    data_aux = []
    x_ = []
    y_ = []

    ret, frame = cap.read()
    if not ret:
        break

    H, W, _ = frame.shape

    frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

    results = hands.process(frame_rgb)
    if results.multi_hand_landmarks:
        for hand_landmarks in results.multi_hand_landmarks:
            mp_drawing.draw_landmarks(
                frame,
                hand_landmarks,
                mp_hands.HAND_CONNECTIONS,
                mp_drawing_styles.get_default_hand_landmarks_style(),
                mp_drawing_styles.get_default_hand_connections_style(),
            )

            for i in range(len(hand_landmarks.landmark)):
                x = hand_landmarks.landmark[i].x
                y = hand_landmarks.landmark[i].y

                x_.append(x)
                y_.append(y)
            
            for i in range(len(hand_landmarks.landmark)):
                x = hand_landmarks.landmark[i].x
                y = hand_landmarks.landmark[i].y
                data_aux.append(x - min(x_))
                data_aux.append(y - min(y_))

        x1 = int(min(x_) * W) - 10
        y1 = int(min(y_) * H) - 10
        x2 = int(max(x_) * W) + 10
        y2 = int(max(y_) * H) + 10

        data_aux = np.array(data_aux)
        data_aux = np.reshape(data_aux, (1, -1))

        prediction = model.predict(data_aux)
        prediction_character = labels_dict[int(np.argmax(prediction))]

        cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 0, 0), 4)
        cv2.putText(frame, prediction_character, (x1, y1 - 10), cv2.FONT_HERSHEY_PLAIN, 1.3, (0, 0, 0), 2, cv2.LINE_AA)

    cv2.imshow('frame', frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# Shape of data_aux: (42,)
# Shape after reshaping: (1, 42)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# Shape of data_aux: (42,)
# Shape after reshaping: (1, 42)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Shape of data_aux: (42,)
# Shape after reshaping: (1, 42)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Shape of data_aux: (42,)
# Shape after reshaping: (1, 42)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Shape of data_aux: (42,)
# Shape after reshaping: (1, 42)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Shape of data_aux: (42,)
# Shape after reshaping: (1, 42)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Shape of data_aux: (42,)
# Shape after reshaping: (1, 42)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Shape of data_aux: (42,)
# Shape after reshaping: (1, 42)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Shape of data_aux: (42,)
# Shape after reshaping: (1, 42)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Shape of data_aux: (42,)
# Shape after reshaping: (1, 42)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# ...
